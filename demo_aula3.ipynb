# %%
#!pip install pandas, ydata_profiling, autoviz, ipywidgets
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# C:\Users\Utilizador\AppData\Local\Temp\ipykernel_11716\3289448526.py:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
d = pd.read_csv("train.csv", sep=",")
d.head(5)
# Out:
#     brand               model  model_year      milage fuel_type  \
# 0    Jeep      Wrangler Sport        2014  71,000 mi.  Gasoline
# 1  Toyota      Highlander XLE        2015  68,575 mi.  Gasoline
# 2  Toyota    Camry Hybrid XLE        2018  69,641 mi.    Hybrid
# 3  Subaru  Outback Touring XT        2021  33,500 mi.  Gasoline
# 4   Lexus         GX 460 Base        2018  75,000 mi.  Gasoline
#
#                                               engine      transmission  \
# 0      285.0HP 3.6L V6 Cylinder Engine Gasoline Fuel       5-Speed A/T
# 1      270.0HP 3.5L V6 Cylinder Engine Gasoline Fuel               A/T
# 2  208.0HP 2.5L 4 Cylinder Engine Gas/Electric Hy...  CVT Transmission
# 3       260.0HP 2.4L 4 Cylinder Engine Gasoline Fuel  CVT Transmission
# 4       301.0HP 4.6L 8 Cylinder Engine Gasoline Fuel       6-Speed A/T
#
#   ext_col int_col                                accident clean_title  price
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3207 entries, 0 to 3206
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         3207 non-null   object
#  1   model         3207 non-null   object
#  2   model_year    3207 non-null   int64
#  3   milage        3207 non-null   object
#  4   fuel_type     3060 non-null   object
#  5   engine        3207 non-null   object
#  6   transmission  3207 non-null   object
#  7   ext_col       3207 non-null   object
#  8   int_col       3207 non-null   object
#  9   accident      3118 non-null   object
#  10  clean_title   2740 non-null   object
#  11  price         3207 non-null   int64
# dtypes: int64(2), object(10)
# memory usage: 300.8+ KB

# %%
d.describe()
# Out:
#         model_year         price
# count  3207.000000  3.207000e+03
# mean   2015.517930  4.487024e+04
# std       6.131963  8.382969e+04
# min    1974.000000  2.000000e+03
# 25%    2012.000000  1.705000e+04
# 50%    2017.000000  3.169800e+04
# 75%    2020.000000  4.999650e+04
# max    2024.000000  2.954083e+06

# %%
d[["Age", "Survived"]]
# Out:
#       Age  Survived
# 0    22.0         0
# 1    38.0         1
# 2    26.0         1
# 3    35.0         1
# 4    35.0         0
# ..    ...       ...
# 882  27.0         0
# 883  19.0         1
# 884   7.0         0
# 885  26.0         1
# 886  32.0         0
#
# [887 rows x 2 columns]

# %%
profile = ProfileReport(d, title="Pandas Profiling Report", explorative=True)

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.5&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-02-29 10:54:21.628207&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("train.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported v0.1.806. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
AV = AutoViz_Class()

# %%
# %matplotlib inline

# %%
_ = AV.AutoViz("train.csv", ",", "price")
# Out:
# Shape of your Data Set loaded: (3207, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  3
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  3
#     Number of Date Time Columns =  1
#     Number of ID Columns =  0
#     Number of Columns to Delete =  1
#     11 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['clean_title']
#
# ...
